# %%
import pandas as pd
import numpy as np

df = pd.read_csv('metadata.csv', engine='python', on_bad_lines='skip')
df
# Out:
#         cord_uid                                       sha  \
# 0       ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb
# 1       02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d
# 2       ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927
# 3       2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605
# 4       9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32
# ...          ...                                       ...
# 822306  ahaki321  25d1a8d113e72ba1c9168cb4a66f4b67e2e711b7
# 822307  wprnxnhm  e3ea7edc4259fa4dbcceccfdbae06e5cb5e24fc6
# 822308  d4z2lwju  49b1a6616042c834b93631be6272a2f38bcadf8b
# 822309  olymwmgj  87f5f5bccabf6281b2f09fb3ffec40a6765a960e
# 822310  47wklq0n  986dafe1bf688519d87f0ec541b947b993657558
#
#                       source_x  \
# 0                          PMC
# 1                          PMC
# 2                          PMC
# 3                          PMC
# 4                          PMC
# ...                        ...
# 822306            Medline; PMC
# 822307       Medline; PMC; WHO
# 822308       Medline; PMC; WHO
# 822309  Elsevier; Medline; PMC
# 822310  Elsevier; Medline; PMC
#
#                                                     title  \
# 0       Clinical features of culture-proven Mycoplasma...
# 1       Nitric oxide: a pro-inflammatory mediator in l...
# 2         Surfactant protein-D and pulmonary host defense
# 3                    Role of endothelin-1 in lung disease
# 4       Gene expression in epithelial cells in respons...
# ...                                                   ...
# 822306  Multimodality cardiac imaging for management o...
# 822307  Systemic Immune Response Syndrome After COVID-...
# 822308  Health-BlockEdge: Blockchain-Edge Framework fo...
# 822309  Children and young people remain at low risk o...
# 822310  Impact of Rapid Transition to Telemedicine-Bas...
#
#                                   doi       pmcid pubmed_id    license  \
# 0               10.1186/1471-2334-1-6    PMC35282  11472636      no-cc
# 1                        10.1186/rr14    PMC59543  11667967      no-cc
# 2                        10.1186/rr19    PMC59549  11667972      no-cc
# 3                        10.1186/rr44    PMC59574  11686871      no-cc
# 4                        10.1186/rr61    PMC59580  11686888      no-cc
# ...                               ...         ...       ...        ...
# 822306          10.1093/ehjcr/ytab062  PMC8108618  34104862   cc-by-nc
# 822307   10.1097/rlu.0000000000004032  PMC8820747  35025792      no-cc
# 822308              10.3390/s21072502  PMC8038371  33916700      cc-by
# 822309  10.1016/s2352-4642(21)00066-3  PMC7946566  33713603      no-cc
# 822310     10.1016/j.jaip.2021.04.018  PMC8061180  33894393  els-covid
#
#                                                  abstract publish_time  \
# 0       OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1       Inflammatory diseases of the respiratory tract...   2000-08-15
# 2       Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3       Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4       Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
# ...                                                   ...          ...
# 822306  BACKGROUND : Atrial myxomas are the most commo...   2021-03-04
# 822307  A 46-year-old woman with previous history of b...   2022-01-13
# 822308  The rapid evolution of technology allows the h...   2021-04-03
# 822309                                                NaN   2021-03-11
# 822310  Background COVID-19 necessitated widescale ado...   2021-04-22
#
#                                                   authors  \
# 0                     Madani, Tariq A; Al-Ghamdi, Aisha A
# 1       Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                         Crouch, Erika C
# 3       Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4       Domachowske, Joseph B; Bonville, Cynthia A; Ro...
# ...                                                   ...
# 822306  Ranjan, Pragya; LaRocca, Gina; Sanz, Javier; C...
# 822307  Nawwar, Ayah Adel; Searle, Julie; Hagan, Ian; ...
# 822308  Ejaz, Muneeb; Kumar, Tanesh; Kovacevic, Ivana;...
# 822309  Bhopal, Sunil S; Bagaria, Jayshree; Olabi, Bay...
# 822310  Tsao, Lulu R.; Villanueva, Stephanie Anne; Pin...
#
#                              journal  mag_id who_covidence_id arxiv_id  \
# 0                     BMC Infect Dis     NaN              NaN      NaN
# 1                         Respir Res     NaN              NaN      NaN
# 2                         Respir Res     NaN              NaN      NaN
# 3                         Respir Res     NaN              NaN      NaN
# 4                         Respir Res     NaN              NaN      NaN
# ...                              ...     ...              ...      ...
# 822306          Eur Heart J Case Rep     NaN              NaN      NaN
# 822307                 Clin Nucl Med     NaN              NaN      NaN
# 822308               Sensors (Basel)     NaN              NaN      NaN
# 822309   Lancet Child Adolesc Health     NaN              NaN      NaN
# 822310  J Allergy Clin Immunol Pract     NaN              NaN      NaN
#
#                                            pdf_json_files  \
# 0       document_parses/pdf_json/d1aafb70c066a2068b027...
# 1       document_parses/pdf_json/6b0567729c2143a66d737...
# 2       document_parses/pdf_json/06ced00a5fc04215949aa...
# 3       document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4       document_parses/pdf_json/5f48792a5fa08bed9f560...
# ...                                                   ...
# 822306  document_parses/pdf_json/25d1a8d113e72ba1c9168...
# 822307  document_parses/pdf_json/e3ea7edc4259fa4dbccec...
# 822308  document_parses/pdf_json/49b1a6616042c834b9363...
# 822309  document_parses/pdf_json/87f5f5bccabf6281b2f09...
# 822310  document_parses/pdf_json/986dafe1bf688519d87f0...
#
#                                       pmc_json_files  \
# 0         document_parses/pmc_json/PMC35282.xml.json
# 1         document_parses/pmc_json/PMC59543.xml.json
# 2         document_parses/pmc_json/PMC59549.xml.json
# 3         document_parses/pmc_json/PMC59574.xml.json
# 4         document_parses/pmc_json/PMC59580.xml.json
# ...                                              ...
# 822306  document_parses/pmc_json/PMC8108618.xml.json
# 822307                                           NaN
# 822308  document_parses/pmc_json/PMC8038371.xml.json
# 822309  document_parses/pmc_json/PMC7946566.xml.json
# 822310                                           NaN
#
#                                                       url        s2_id
# 0       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...          NaN
# 1       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 2       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 3       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 4       https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# ...                                                   ...          ...
# 822306  https://www.ncbi.nlm.nih.gov/pubmed/34104862/;...  233808518.0
# 822307  https://doi.org/10.1097/rlu.0000000000004032; ...  245933243.0
# 822308  https://www.ncbi.nlm.nih.gov/pubmed/33916700/;...  233208456.0
# 822309  https://doi.org/10.1016/s2352-4642(21)00066-3;...  232171017.0
# 822310  https://www.sciencedirect.com/science/article/...  233353831.0
#
# [822311 rows x 19 columns]

# %%
df.head(6)
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
# 5  zjufx4fo  b2897e1277f56641193a6db73825f707eed3e4c9      PMC
#
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# 4  Gene expression in epithelial cells in respons...
# 5  Sequence requirements for RNA strand transfer ...
#
#                         doi      pmcid pubmed_id   license  \
# 0     10.1186/1471-2334-1-6   PMC35282  11472636     no-cc
# 1              10.1186/rr14   PMC59543  11667967     no-cc
# 2              10.1186/rr19   PMC59549  11667972     no-cc
# 3              10.1186/rr44   PMC59574  11686871     no-cc
# 4              10.1186/rr61   PMC59580  11686888     no-cc
# 5  10.1093/emboj/20.24.7220  PMC125340  11742998  green-oa
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4  Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
# 5  Nidovirus subgenomic mRNAs contain a leader se...   2001-12-17
#
#                                              authors           journal  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A    BMC Infect Dis
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...        Respir Res
# 2                                    Crouch, Erika C        Respir Res
# 3  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M        Respir Res
# 4  Domachowske, Joseph B; Bonville, Cynthia A; Ro...        Respir Res
# 5  Pasternak, Alexander O.; van den Born, Erwin; ...  The EMBO Journal
#
#    mag_id who_covidence_id arxiv_id  \
# 0     NaN              NaN      NaN
# 1     NaN              NaN      NaN
# 2     NaN              NaN      NaN
# 3     NaN              NaN      NaN
# 4     NaN              NaN      NaN
# 5     NaN              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
# 3  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4  document_parses/pdf_json/5f48792a5fa08bed9f560...
# 5  document_parses/pdf_json/b2897e1277f56641193a6...
#
#                                 pmc_json_files  \
# 0   document_parses/pmc_json/PMC35282.xml.json
# 1   document_parses/pmc_json/PMC59543.xml.json
# 2   document_parses/pmc_json/PMC59549.xml.json
# 3   document_parses/pmc_json/PMC59574.xml.json
# 4   document_parses/pmc_json/PMC59580.xml.json
# 5  document_parses/pmc_json/PMC125340.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 5  http://europepmc.org/articles/pmc125340?pdf=re...    NaN

# %%
df.describe()
# Out:
#        mag_id         s2_id
# count     0.0  7.421190e+05
# mean      NaN  2.167257e+08
# std       NaN  5.312428e+07
# min       NaN  9.600000e+01
# 25%       NaN  2.210744e+08
# 50%       NaN  2.317901e+08
# 75%       NaN  2.362153e+08
# max       NaN  2.491936e+08

# %%
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# mag_id              822311
# arxiv_id            808694
# pmc_json_files      665425
# sha                 630468
# pdf_json_files      630468
# pmcid               623089
# pubmed_id           530147
# doi                 399495
# url                 369726
# who_covidence_id    362797
# dtype: int64

# %%
# Keep relevant columns
df_clean = df[["title", "abstract", "publish_time", "authors", "journal", "source_x"]].copy()

# Drop rows without title or publish_time
df_clean.dropna(subset=["title", "publish_time"], inplace=True)

# Convert dates
df_clean["publish_time"] = pd.to_datetime(df_clean["publish_time"], errors="coerce")
df_clean["year"] = df_clean["publish_time"].dt.year

# Word count in abstract
df_clean["abstract_word_count"] = df_clean["abstract"].fillna("").apply(lambda x: len(x.split()))

# %%
# %pip install matplotlib seaborn wordcloud

import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Publications per year
year_counts = df_clean["year"].value_counts().sort_index()
plt.bar(year_counts.index, year_counts.values)
plt.title("Publications by Year")
plt.show()

# Top journals
top_journals = df_clean["journal"].value_counts().head(10)
sns.barplot(y=top_journals.index, x=top_journals.values)
plt.title("Top 10 Journals")
plt.show()

# Word cloud of titles
all_titles = " ".join(df_clean["title"].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(all_titles)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# Paper distribution by source
df_clean["source_x"].value_counts().plot(kind="bar", figsize=(10,4), title="Publications by Source")
plt.show()
# Out:
# Requirement already satisfied: matplotlib in /home/nato/.venv/lib/python3.12/site-packages (3.10.6)
# Requirement already satisfied: seaborn in /home/nato/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: wordcloud in /home/nato/.venv/lib/python3.12/site-packages (1.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nato/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/nato/.venv/lib/python3.12/site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pytz>=2020.1 in /home/nato/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/nato/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/nato/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
